# %%
import sys
import os
os.chdir('..')
sys.path.append('py//models')
from model_funs import *
X, y = get_x_y('data_for_modelling')
X_hold, y_hold = get_x_y('holdout')

# %%
mae_results_dict = dict()
for i in range(1, 31):
    patterns_components = [['parks', min(i, 9)], 
                           ['edu', min(i, 6)],
                           ['shops', min(i, 5)],
                           ['moscow_stations', min(i, 5)],
                           ['bus_stops', min(i, 5)],
                           ['eco', min(i, 5)],
                           ['hospitals',  min(i, 2)]
                          ]
    pca_groups1 = get_PCA_groups(X, patterns_components)
    for j in range(1, 11):
        for k, pca_group in enumerate([pca_groups1, get_PCA_groups(X, ('all', i))]):
            print(f"PCA components: {i}, k_best: {j}")
            
            if (1 == 0
                or (k == 1 and j > i)
                or (k == 0 and i >= 10)
               ):
                print(f"skipping PCA components: {i}, k_best: {j}, pca_group: {k+1}")
                print("")
                print("")
                continue
                
            model = get_model_pipeline(X, 
                                       KNeighborsRegressor(), 
                                       pca_groups = pca_group,
                                       feature_selection = ('k_best', j)
                    )
            param_grid = {'model__n_neighbors': np.arange(5, 70),  
                          'model__weights': ['uniform', 'distance'], 
                          'model__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']  
                          }
            
            grid_search = GridSearchCV(model, 
                                       param_grid, 
                                       cv = 5, 
                                       scoring = 'neg_mean_absolute_error', 
                                       return_train_score = False,
                                       verbose = 1,
                                       n_jobs = 5
                         )
            grid_search.fit(X, y)
            
            print("Best Parameters:", grid_search.best_params_)
            print("Best MAE: {:.2f}".format(-grid_search.best_score_))
            mae_results_dict[f"{i}, {j}, {k}"] = -grid_search.best_score_
            
            print("")
            print("")
# Out:
# PCA components: 1, k_best: 1
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 1, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513]
# all: Cumulative Explained Variance: 0.2663
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 1, k_best: 2
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 1, k_best: 2
# skipping PCA components: 1, k_best: 2, pca_group: 2
#
#
# PCA components: 1, k_best: 3
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28847.45
#
#
# PCA components: 1, k_best: 3
# skipping PCA components: 1, k_best: 3, pca_group: 2
#
#
# PCA components: 1, k_best: 4
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 67, 'model__weights': 'distance'}
# Best MAE: 28030.43
#
#
# PCA components: 1, k_best: 4
# skipping PCA components: 1, k_best: 4, pca_group: 2
#
#
# PCA components: 1, k_best: 5
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 27122.16
#
#
# PCA components: 1, k_best: 5
# skipping PCA components: 1, k_best: 5, pca_group: 2
#
#
# PCA components: 1, k_best: 6
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 28, 'model__weights': 'distance'}
# Best MAE: 27002.97
#
#
# PCA components: 1, k_best: 6
# skipping PCA components: 1, k_best: 6, pca_group: 2
#
#
# PCA components: 1, k_best: 7
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26660.48
#
#
# PCA components: 1, k_best: 7
# skipping PCA components: 1, k_best: 7, pca_group: 2
#
#
# PCA components: 1, k_best: 8
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26571.85
#
#
# PCA components: 1, k_best: 8
# skipping PCA components: 1, k_best: 8, pca_group: 2
#
#
# PCA components: 1, k_best: 9
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26490.75
#
#
# PCA components: 1, k_best: 9
# skipping PCA components: 1, k_best: 9, pca_group: 2
#
#
# PCA components: 1, k_best: 10
# parks: Explained Variance Ratio per Component: [0.32376045]
# parks: Cumulative Explained Variance: 0.3238
# edu: Explained Variance Ratio per Component: [0.52977431]
# edu: Cumulative Explained Variance: 0.5298
# shops: Explained Variance Ratio per Component: [0.395567]
# shops: Cumulative Explained Variance: 0.3956
# moscow_stations: Explained Variance Ratio per Component: [0.50439374]
# moscow_stations: Cumulative Explained Variance: 0.5044
# bus_stops: Explained Variance Ratio per Component: [0.49780078]
# bus_stops: Cumulative Explained Variance: 0.4978
# eco: Explained Variance Ratio per Component: [0.49611701]
# eco: Cumulative Explained Variance: 0.4961
# hospitals: Explained Variance Ratio per Component: [0.76014283]
# hospitals: Cumulative Explained Variance: 0.7601
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26456.38
#
#
# PCA components: 1, k_best: 10
# skipping PCA components: 1, k_best: 10, pca_group: 2
#
#
# PCA components: 2, k_best: 1
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 2, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238]
# all: Cumulative Explained Variance: 0.3186
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 2, k_best: 2
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 2, k_best: 2
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238]
# all: Cumulative Explained Variance: 0.3186
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28653.01
#
#
# PCA components: 2, k_best: 3
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28847.45
#
#
# PCA components: 2, k_best: 3
# skipping PCA components: 2, k_best: 3, pca_group: 2
#
#
# PCA components: 2, k_best: 4
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 67, 'model__weights': 'distance'}
# Best MAE: 28030.43
#
#
# PCA components: 2, k_best: 4
# skipping PCA components: 2, k_best: 4, pca_group: 2
#
#
# PCA components: 2, k_best: 5
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 27122.16
#
#
# PCA components: 2, k_best: 5
# skipping PCA components: 2, k_best: 5, pca_group: 2
#
#
# PCA components: 2, k_best: 6
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 28, 'model__weights': 'distance'}
# Best MAE: 27002.97
#
#
# PCA components: 2, k_best: 6
# skipping PCA components: 2, k_best: 6, pca_group: 2
#
#
# PCA components: 2, k_best: 7
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26660.48
#
#
# PCA components: 2, k_best: 7
# skipping PCA components: 2, k_best: 7, pca_group: 2
#
#
# PCA components: 2, k_best: 8
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26571.85
#
#
# PCA components: 2, k_best: 8
# skipping PCA components: 2, k_best: 8, pca_group: 2
#
#
# PCA components: 2, k_best: 9
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26490.75
#
#
# PCA components: 2, k_best: 9
# skipping PCA components: 2, k_best: 9, pca_group: 2
#
#
# PCA components: 2, k_best: 10
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045]
# parks: Cumulative Explained Variance: 0.5140
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055]
# edu: Cumulative Explained Variance: 0.6949
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622]
# shops: Cumulative Explained Variance: 0.6046
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457]
# moscow_stations: Cumulative Explained Variance: 0.7289
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003]
# bus_stops: Cumulative Explained Variance: 0.7341
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603]
# eco: Cumulative Explained Variance: 0.7147
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26456.38
#
#
# PCA components: 2, k_best: 10
# skipping PCA components: 2, k_best: 10, pca_group: 2
#
#
# PCA components: 3, k_best: 1
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 3, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797]
# all: Cumulative Explained Variance: 0.3671
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 3, k_best: 2
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 3, k_best: 2
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797]
# all: Cumulative Explained Variance: 0.3671
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28653.01
#
#
# PCA components: 3, k_best: 3
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28847.45
#
#
# PCA components: 3, k_best: 3
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797]
# all: Cumulative Explained Variance: 0.3671
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 18, 'model__weights': 'distance'}
# Best MAE: 27027.01
#
#
# PCA components: 3, k_best: 4
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 67, 'model__weights': 'distance'}
# Best MAE: 28030.43
#
#
# PCA components: 3, k_best: 4
# skipping PCA components: 3, k_best: 4, pca_group: 2
#
#
# PCA components: 3, k_best: 5
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 27122.16
#
#
# PCA components: 3, k_best: 5
# skipping PCA components: 3, k_best: 5, pca_group: 2
#
#
# PCA components: 3, k_best: 6
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 28, 'model__weights': 'distance'}
# Best MAE: 27002.97
#
#
# PCA components: 3, k_best: 6
# skipping PCA components: 3, k_best: 6, pca_group: 2
#
#
# PCA components: 3, k_best: 7
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26660.48
#
#
# PCA components: 3, k_best: 7
# skipping PCA components: 3, k_best: 7, pca_group: 2
#
#
# PCA components: 3, k_best: 8
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26571.85
#
#
# PCA components: 3, k_best: 8
# skipping PCA components: 3, k_best: 8, pca_group: 2
#
#
# PCA components: 3, k_best: 9
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26490.75
#
#
# PCA components: 3, k_best: 9
# skipping PCA components: 3, k_best: 9, pca_group: 2
#
#
# PCA components: 3, k_best: 10
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849]
# parks: Cumulative Explained Variance: 0.6641
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048]
# edu: Cumulative Explained Variance: 0.7923
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344]
# shops: Cumulative Explained Variance: 0.7802
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375]
# moscow_stations: Cumulative Explained Variance: 0.8724
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466 ]
# bus_stops: Cumulative Explained Variance: 0.8609
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066]
# eco: Cumulative Explained Variance: 0.8756
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26456.38
#
#
# PCA components: 3, k_best: 10
# skipping PCA components: 3, k_best: 10, pca_group: 2
#
#
# PCA components: 4, k_best: 1
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 4, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679]
# all: Cumulative Explained Variance: 0.4074
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 4, k_best: 2
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 4, k_best: 2
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679]
# all: Cumulative Explained Variance: 0.4074
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28653.01
#
#
# PCA components: 4, k_best: 3
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28847.45
#
#
# PCA components: 4, k_best: 3
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679]
# all: Cumulative Explained Variance: 0.4074
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 18, 'model__weights': 'distance'}
# Best MAE: 27027.01
#
#
# PCA components: 4, k_best: 4
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 67, 'model__weights': 'distance'}
# Best MAE: 28030.43
#
#
# PCA components: 4, k_best: 4
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679]
# all: Cumulative Explained Variance: 0.4074
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26724.17
#
#
# PCA components: 4, k_best: 5
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 27122.16
#
#
# PCA components: 4, k_best: 5
# skipping PCA components: 4, k_best: 5, pca_group: 2
#
#
# PCA components: 4, k_best: 6
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 28, 'model__weights': 'distance'}
# Best MAE: 27002.97
#
#
# PCA components: 4, k_best: 6
# skipping PCA components: 4, k_best: 6, pca_group: 2
#
#
# PCA components: 4, k_best: 7
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# eco: Cumulative Explained Variance: 0.9529
# hospitals: Explained Variance Ratio per Component: [0.76014283 0.23985717]
# hospitals: Cumulative Explained Variance: 1.0000
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26660.48
#
#
# PCA components: 4, k_best: 7
# skipping PCA components: 4, k_best: 7, pca_group: 2
#
#
# PCA components: 4, k_best: 8
# parks: Explained Variance Ratio per Component: [0.32376045 0.19020045 0.15013849 0.08290335]
# parks: Cumulative Explained Variance: 0.7470
# edu: Explained Variance Ratio per Component: [0.52977431 0.16517055 0.09737048 0.0793241 ]
# edu: Cumulative Explained Variance: 0.8716
# shops: Explained Variance Ratio per Component: [0.395567   0.20900622 0.17562344 0.15392766]
# shops: Cumulative Explained Variance: 0.9341
# moscow_stations: Explained Variance Ratio per Component: [0.50439374 0.22453457 0.14348375 0.09300677]
# moscow_stations: Cumulative Explained Variance: 0.9654
# bus_stops: Explained Variance Ratio per Component: [0.49780078 0.23631003 0.1267466  0.1090351 ]
# bus_stops: Cumulative Explained Variance: 0.9699
# eco: Explained Variance Ratio per Component: [0.49611701 0.21861603 0.16083066 0.07733678]
# ...
#
#
# PCA components: 28, k_best: 9
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214]
# all: Cumulative Explained Variance: 0.8865
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best MAE: 27182.77
#
#
# PCA components: 28, k_best: 10
# skipping PCA components: 28, k_best: 10, pca_group: 1
#
#
# PCA components: 28, k_best: 10
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214]
# all: Cumulative Explained Variance: 0.8865
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 8, 'model__weights': 'distance'}
# Best MAE: 27457.99
#
#
# PCA components: 29, k_best: 1
# skipping PCA components: 29, k_best: 1, pca_group: 1
#
#
# PCA components: 29, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 29, k_best: 2
# skipping PCA components: 29, k_best: 2, pca_group: 1
#
#
# PCA components: 29, k_best: 2
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28653.01
#
#
# PCA components: 29, k_best: 3
# skipping PCA components: 29, k_best: 3, pca_group: 1
#
#
# PCA components: 29, k_best: 3
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 18, 'model__weights': 'distance'}
# Best MAE: 27027.01
#
#
# PCA components: 29, k_best: 4
# skipping PCA components: 29, k_best: 4, pca_group: 1
#
#
# PCA components: 29, k_best: 4
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26724.17
#
#
# PCA components: 29, k_best: 5
# skipping PCA components: 29, k_best: 5, pca_group: 1
#
#
# PCA components: 29, k_best: 5
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26494.99
#
#
# PCA components: 29, k_best: 6
# skipping PCA components: 29, k_best: 6, pca_group: 1
#
#
# PCA components: 29, k_best: 6
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 13, 'model__weights': 'distance'}
# Best MAE: 26247.51
#
#
# PCA components: 29, k_best: 7
# skipping PCA components: 29, k_best: 7, pca_group: 1
#
#
# PCA components: 29, k_best: 7
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 11, 'model__weights': 'distance'}
# Best MAE: 26000.37
#
#
# PCA components: 29, k_best: 8
# skipping PCA components: 29, k_best: 8, pca_group: 1
#
#
# PCA components: 29, k_best: 8
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best MAE: 26346.50
#
#
# PCA components: 29, k_best: 9
# skipping PCA components: 29, k_best: 9, pca_group: 1
#
#
# PCA components: 29, k_best: 9
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# C:\Users\UBAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best MAE: 27182.77
#
#
# PCA components: 29, k_best: 10
# skipping PCA components: 29, k_best: 10, pca_group: 1
#
#
# PCA components: 29, k_best: 10
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854]
# all: Cumulative Explained Variance: 0.8966
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 8, 'model__weights': 'distance'}
# Best MAE: 27457.99
#
#
# PCA components: 30, k_best: 1
# skipping PCA components: 30, k_best: 1, pca_group: 1
#
#
# PCA components: 30, k_best: 1
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 59, 'model__weights': 'uniform'}
# Best MAE: 34199.43
#
#
# PCA components: 30, k_best: 2
# skipping PCA components: 30, k_best: 2, pca_group: 1
#
#
# PCA components: 30, k_best: 2
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 28653.01
#
#
# PCA components: 30, k_best: 3
# skipping PCA components: 30, k_best: 3, pca_group: 1
#
#
# PCA components: 30, k_best: 3
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 18, 'model__weights': 'distance'}
# Best MAE: 27027.01
#
#
# PCA components: 30, k_best: 4
# skipping PCA components: 30, k_best: 4, pca_group: 1
#
#
# PCA components: 30, k_best: 4
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26724.17
#
#
# PCA components: 30, k_best: 5
# skipping PCA components: 30, k_best: 5, pca_group: 1
#
#
# PCA components: 30, k_best: 5
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 26494.99
#
#
# PCA components: 30, k_best: 6
# skipping PCA components: 30, k_best: 6, pca_group: 1
#
#
# PCA components: 30, k_best: 6
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 13, 'model__weights': 'distance'}
# Best MAE: 26247.51
#
#
# PCA components: 30, k_best: 7
# skipping PCA components: 30, k_best: 7, pca_group: 1
#
#
# PCA components: 30, k_best: 7
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 11, 'model__weights': 'distance'}
# Best MAE: 26000.37
#
#
# PCA components: 30, k_best: 8
# skipping PCA components: 30, k_best: 8, pca_group: 1
#
#
# PCA components: 30, k_best: 8
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best MAE: 26346.50
#
#
# PCA components: 30, k_best: 9
# skipping PCA components: 30, k_best: 9, pca_group: 1
#
#
# PCA components: 30, k_best: 9
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best MAE: 27182.77
#
#
# PCA components: 30, k_best: 10
# skipping PCA components: 30, k_best: 10, pca_group: 1
#
#
# PCA components: 30, k_best: 10
# all: Explained Variance Ratio per Component: [0.26631513 0.05228238 0.04848797 0.04032679 0.03567258 0.03185733
#  0.03038466 0.02864614 0.02765526 0.02595187 0.02261373 0.02107434
#  0.02082944 0.02017183 0.0196376  0.01917968 0.01842216 0.01795865
#  0.01779245 0.01736454 0.0159068  0.01459242 0.01396678 0.01305534
#  0.01287868 0.01167468 0.01117525 0.01066214 0.01008854 0.00959   ]
# all: Cumulative Explained Variance: 0.9062
# Fitting 5 folds for each of 520 candidates, totalling 2600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 8, 'model__weights': 'distance'}
# Best MAE: 27457.99

# %%
mae_df = pd.DataFrame.from_dict(mae_results_dict, orient = 'index', columns = ['MAE']).reset_index()
mae_df[['PCA components', 'k_best', 'groupwise PCA']] = mae_df['index'].str.split(', ', expand = True).astype(int)
mae_df.to_csv("csv//models//KNN_k_best_results.csv", index = False)

              
mae_df = mae_df.drop(['index'], axis = 1)

# Function to plot MAE vs k_best with PCA components as lines
def plot_combined_mae(df):
    plt.figure(figsize=(10, 6))

    # Plot for groupwise PCA = 0
    subset_0 = df.query("`groupwise PCA` == 0")
    for pca in subset_0['PCA components'].unique():
        group = subset_0[subset_0['PCA components'] == pca]
        plt.plot(group['k_best'], group['MAE'], marker='o', linestyle='-', label=f'groupwise=0, PCA={pca}', color = 'blue')

    # Plot for groupwise PCA = 1
    subset_1 = df.query("`groupwise PCA` == 1")
    for pca in subset_1['PCA components'].unique():
        group = subset_1[subset_1['PCA components'] == pca]
        plt.plot(group['k_best'], group['MAE'], marker='o', linestyle='-', label=f'groupwise=1, PCA={pca}', color = 'darkgreen')

    # Labels and grid
    plt.title('MAE vs k_best')
    plt.grid()
    plt.tight_layout()


plot_combined_mae(mae_df)

from matplotlib.lines import Line2D
custom_legend = [
    Line2D([0], [0], color='blue', linestyle='-', marker='o', label='Total PCA'),
    Line2D([0], [0], color='darkgreen', linestyle='-', marker='o', label='Groupwise PCA')
]
plt.legend(handles = custom_legend, loc = "upper right")
plt.show()

# %%
res_dict = dict()
for col_comb in get_combs_list(X.columns.to_list(), 1):
    res_dict[','.join(col_comb)] = fit_and_eval_knn_on_given_cols(X, y, col_comb)
# Out:
# checking ['floor']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 162, 'model__weights': 'uniform'}
# Best MAE: 46598.49
#
#
# checking ['floors_total']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 173, 'model__weights': 'distance'}
# Best MAE: 41519.51
#
#
# checking ['meters']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 57, 'model__weights': 'uniform'}
# Best MAE: 34207.35
#
#
# checking ['center_dist']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 38402.29
#
#
# checking ['adult_hospitals_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 44514.14
#
#
# checking ['bus_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 70, 'model__weights': 'distance'}
# Best MAE: 40330.52
#
#
# checking ['bus_stops_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 45590.99
#
#
# checking ['bus_stops_less500m']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 115, 'model__weights': 'uniform'}
# Best MAE: 48084.27
#
#
# checking ['bus_stops_0.5-1km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 71, 'model__weights': 'uniform'}
# Best MAE: 47444.01
#
#
# checking ['bus_stops_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 24, 'model__weights': 'uniform'}
# Best MAE: 43688.59
#
#
# checking ['bus_stops_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 30, 'model__weights': 'uniform'}
# Best MAE: 43234.63
#
#
# checking ['eco_boiler_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 41669.23
#
#
# checking ['eco_dump_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 41917.18
#
#
# checking ['eco_factory_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 44834.35
#
#
# checking ['eco_thermal_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 45074.37
#
#
# checking ['eco_waste_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 42985.00
#
#
# checking ['edu_prof_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 44854.00
#
#
# checking ['edu_prof_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 45333.02
#
#
# checking ['edu_prof_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 166, 'model__weights': 'uniform'}
# Best MAE: 44660.18
#
#
# checking ['edu_school_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 197, 'model__weights': 'distance'}
# Best MAE: 44868.96
#
#
# checking ['edu_school_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 123, 'model__weights': 'distance'}
# Best MAE: 45014.70
#
#
# checking ['edu_school_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 88, 'model__weights': 'distance'}
# Best MAE: 42335.69
#
#
# checking ['kids_hospitals_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 42839.04
#
#
# checking ['moscow_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 44247.56
#
#
# checking ['moscow_stations_less500m']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 194, 'model__weights': 'distance'}
# Best MAE: 64261.03
#
#
# checking ['moscow_stations_0.5-1km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 51934.74
#
#
# checking ['moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 124, 'model__weights': 'uniform'}
# Best MAE: 40818.67
#
#
# checking ['moscow_stations_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 135, 'model__weights': 'uniform'}
# Best MAE: 41399.16
#
#
# checking ['parks_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 45742.58
#
#
# checking ['parks_less500m']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 50017.58
#
#
# checking ['parks_0.5-1km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 45167.57
#
#
# checking ['parks_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 58, 'model__weights': 'distance'}
# Best MAE: 41298.08
#
#
# checking ['parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 26, 'model__weights': 'uniform'}
# Best MAE: 40966.91
#
#
# checking ['parks_area_less500m']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 43792.86
#
#
# checking ['parks_area_0.5-1km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 165, 'model__weights': 'distance'}
# Best MAE: 42757.02
#
#
# checking ['parks_area_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 194, 'model__weights': 'distance'}
# Best MAE: 43742.80
#
#
# checking ['parks_area_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 43986.51
#
#
# checking ['shops_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 45155.39
#
#
# checking ['shops_less500m']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 37, 'model__weights': 'distance'}
# Best MAE: 47216.26
#
#
# checking ['shops_0.5-1km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 25, 'model__weights': 'uniform'}
# Best MAE: 48218.83
#
#
# checking ['shops_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 138, 'model__weights': 'uniform'}
# Best MAE: 43997.99
#
#
# checking ['shops_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 24, 'model__weights': 'uniform'}
# Best MAE: 43622.97
#
#
# checking ['train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 40862.78
#
#
# checking ['is_duplicated']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 74345.32
#
#
# checking ['other_flats_at_this_coords']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 66064.92
#
#
# checking ['author_type_homeowner']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 73779.37
#
#
# checking ['author_type_many_types']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 74345.32
#
#
# checking ['author_type_official_representative']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 74340.44
#
#
# checking ['author_type_real_estate_agent']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 62753.93
#
#
# checking ['author_type_realtor']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 199, 'model__weights': 'uniform'}
# Best MAE: 67552.60
#
#
# checking ['author_type_unknown']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 11, 'model__weights': 'uniform'}
# Best MAE: 72557.75
#
#
# checking ['rooms_1']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 57206.87
#
#
# checking ['rooms_2']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 10, 'model__weights': 'uniform'}
# Best MAE: 63650.87
#
#
# checking ['rooms_3']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'uniform'}
# Best MAE: 72588.27
#
#
# checking ['rooms_4']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 16, 'model__weights': 'uniform'}
# Best MAE: 43708.41
#
#
# checking ['rooms_5']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 14, 'model__weights': 'distance'}
# Best MAE: 74312.22

# %%
top_6_features = [x[0] for x in sorted(res_dict.items(), key = lambda x: x[1])[:6]]
knn_mae_dict = dict()
for col_comb in get_combs_list(top_6_features):
    knn_mae_dict[','.join(col_comb)] = fit_and_eval_knn_on_given_cols(X, y, col_comb)
# Out:
# checking ['meters']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 57, 'model__weights': 'uniform'}
# Best MAE: 34207.35
#
#
# checking ['center_dist']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 38402.29
#
#
# checking ['bus_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 70, 'model__weights': 'distance'}
# Best MAE: 40330.52
#
#
# checking ['moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 124, 'model__weights': 'uniform'}
# Best MAE: 40818.67
#
#
# checking ['train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 40862.78
#
#
# checking ['parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 26, 'model__weights': 'uniform'}
# Best MAE: 40966.91
#
#
# checking ['meters', 'center_dist']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 27, 'model__weights': 'uniform'}
# Best MAE: 27399.02
#
#
# checking ['meters', 'bus_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 28, 'model__weights': 'uniform'}
# Best MAE: 29622.99
#
#
# checking ['meters', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 47, 'model__weights': 'uniform'}
# Best MAE: 28415.94
#
#
# checking ['meters', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 90, 'model__weights': 'distance'}
# Best MAE: 28916.58
#
#
# checking ['meters', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 58, 'model__weights': 'uniform'}
# Best MAE: 27888.75
#
#
# checking ['center_dist', 'bus_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 69, 'model__weights': 'distance'}
# Best MAE: 36417.18
#
#
# checking ['center_dist', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 38079.16
#
#
# checking ['center_dist', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 23, 'model__weights': 'distance'}
# Best MAE: 36942.93
#
#
# checking ['center_dist', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 132, 'model__weights': 'distance'}
# Best MAE: 37720.84
#
#
# checking ['bus_stations_closest_km', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 199, 'model__weights': 'distance'}
# Best MAE: 37716.80
#
#
# checking ['bus_stations_closest_km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 36, 'model__weights': 'distance'}
# Best MAE: 36672.68
#
#
# checking ['bus_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 198, 'model__weights': 'distance'}
# Best MAE: 37310.32
#
#
# checking ['moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 171, 'model__weights': 'distance'}
# Best MAE: 38629.82
#
#
# checking ['moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 11, 'model__weights': 'uniform'}
# Best MAE: 40436.12
#
#
# checking ['train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 74, 'model__weights': 'distance'}
# Best MAE: 37974.26
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 25651.84
#
#
# checking ['meters', 'center_dist', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 47, 'model__weights': 'distance'}
# Best MAE: 27139.16
#
#
# checking ['meters', 'center_dist', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 26914.86
#
#
# checking ['meters', 'center_dist', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 56, 'model__weights': 'distance'}
# Best MAE: 26796.35
#
#
# checking ['meters', 'bus_stations_closest_km', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 24, 'model__weights': 'distance'}
# Best MAE: 26912.17
#
#
# checking ['meters', 'bus_stations_closest_km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 15, 'model__weights': 'distance'}
# Best MAE: 25707.42
#
#
# checking ['meters', 'bus_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 22, 'model__weights': 'distance'}
# Best MAE: 26203.35
#
#
# checking ['meters', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 51, 'model__weights': 'distance'}
# Best MAE: 27242.81
#
#
# checking ['meters', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 36, 'model__weights': 'uniform'}
# Best MAE: 27495.56
#
#
# checking ['meters', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 43, 'model__weights': 'distance'}
# Best MAE: 26875.86
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 45, 'model__weights': 'distance'}
# Best MAE: 36547.68
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 18, 'model__weights': 'distance'}
# Best MAE: 35956.60
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 58, 'model__weights': 'distance'}
# Best MAE: 36506.54
#
#
# checking ['center_dist', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 48, 'model__weights': 'distance'}
# Best MAE: 37479.38
#
#
# checking ['center_dist', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 173, 'model__weights': 'distance'}
# Best MAE: 37644.13
#
#
# checking ['center_dist', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 26, 'model__weights': 'distance'}
# Best MAE: 37081.97
#
#
# checking ['bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 35, 'model__weights': 'distance'}
# Best MAE: 36495.12
#
#
# checking ['bus_stations_closest_km', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 75, 'model__weights': 'distance'}
# Best MAE: 36810.09
#
#
# checking ['bus_stations_closest_km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 29, 'model__weights': 'distance'}
# Best MAE: 36659.50
#
#
# checking ['moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 37606.98
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 22, 'model__weights': 'distance'}
# Best MAE: 25701.76
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 12, 'model__weights': 'distance'}
# Best MAE: 25326.70
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 25600.85
#
#
# checking ['meters', 'center_dist', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 30, 'model__weights': 'distance'}
# Best MAE: 26803.01
#
#
# checking ['meters', 'center_dist', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 37, 'model__weights': 'distance'}
# Best MAE: 26640.87
#
#
# checking ['meters', 'center_dist', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 27, 'model__weights': 'distance'}
# Best MAE: 26547.88
#
#
# checking ['meters', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 16, 'model__weights': 'distance'}
# Best MAE: 25695.43
#
#
# checking ['meters', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 22, 'model__weights': 'distance'}
# Best MAE: 25969.84
#
#
# checking ['meters', 'bus_stations_closest_km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 10, 'model__weights': 'distance'}
# Best MAE: 25615.77
#
#
# checking ['meters', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 29, 'model__weights': 'distance'}
# Best MAE: 26683.20
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 36379.10
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 41, 'model__weights': 'distance'}
# Best MAE: 36571.42
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 14, 'model__weights': 'distance'}
# Best MAE: 36357.49
#
#
# checking ['center_dist', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 16, 'model__weights': 'distance'}
# Best MAE: 37372.90
#
#
# checking ['bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 31, 'model__weights': 'distance'}
# Best MAE: 36521.43
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 17, 'model__weights': 'distance'}
# Best MAE: 25520.30
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 13, 'model__weights': 'distance'}
# Best MAE: 25531.67
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 13, 'model__weights': 'distance'}
# Best MAE: 25356.28
#
#
# checking ['meters', 'center_dist', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 30, 'model__weights': 'distance'}
# Best MAE: 26521.01
#
#
# checking ['meters', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'auto', 'model__n_neighbors': 12, 'model__weights': 'distance'}
# Best MAE: 25463.48
#
#
# checking ['center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'brute', 'model__n_neighbors': 26, 'model__weights': 'distance'}
# Best MAE: 36404.59
#
#
# checking ['meters', 'center_dist', 'bus_stations_closest_km', 'moscow_stations_1-3km', 'train_stations_closest_km', 'parks_3-5km']
# Fitting 5 folds for each of 1520 candidates, totalling 7600 fits
# Best Parameters: {'model__algorithm': 'ball_tree', 'model__n_neighbors': 12, 'model__weights': 'distance'}
# Best MAE: 25350.34

# %%
print("top 3 models by MAE:")
top3_dict = list(sorted(knn_mae_dict.items(), key = lambda x: x[1])[:3])
top3_dict
# Out:
# top 3 models by MAE:
# [('meters,center_dist,bus_stations_closest_km,train_stations_closest_km',
#   25326.69510133323),
#  ('meters,center_dist,bus_stations_closest_km,moscow_stations_1-3km,train_stations_closest_km,parks_3-5km',
#   25350.33911938547),
#  ('meters,center_dist,bus_stations_closest_km,train_stations_closest_km,parks_3-5km',
#   25356.27636582845)]

# %%
pd.DataFrame.from_dict(knn_mae_dict, orient = 'index', columns = ['MAE']).reset_index().to_csv("csv//models//KNN_alt_selection_results.csv", index = False)

# %%
best_features =  top3_dict[1][0].split(",")

model = get_model_pipeline(X[best_features], KNeighborsRegressor())
param_grid = {'model__n_neighbors': np.arange(1, 40),  
              'model__weights': ['uniform', 'distance'], 
              'model__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']  
              }

grid_search = GridSearchCV(model, 
                           param_grid, 
                           cv = 5, 
                           scoring = 'neg_mean_absolute_error', 
                           return_train_score = False,
                           verbose = 1,
                           n_jobs = 5
             )
grid_search.fit(X[best_features], y)
model = grid_search.best_estimator_
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 312 candidates, totalling 1560 fits
# {'model__algorithm': 'ball_tree', 'model__n_neighbors': 14, 'model__weights': 'distance'}

# %%
errors = model.predict(X_hold[best_features]) - y_hold
print(np.abs(errors).describe())
get_MAE(errors)
get_MAPE(errors, y_hold)
# Out:
# count     1000.0000
# mean     25944.1544
# std      28498.6638
# min          0.0000
# 25%       7515.5541
# 50%      16165.4125
# 75%      32444.7506
# max     205436.2172
# Name: price, dtype: float64
# MAE 25944.15437712421
# MAPE 23.855651083010095%
# 0.23855651083010093

# %%
print(f"errors 95%: {np.quantile(errors, 0.95)}")
print(f"errors 5%: {np.quantile(errors, 0.05)}")
# Out:
# errors 95%: 55985.39770572372
# errors 5%: -70954.6649714838

# %%
for num in np.arange(0, 1000, 100):
    plt.figure(figsize = (15, 8))
    plt.plot(range(100), model.predict(X_hold[best_features])[num:(num + 100)], color = 'red', linestyle = '--')
    plt.plot(range(100), y_hold[num:(num + 100)])
    plt.show()
