# %%
import os
os.chdir('..')
import pandas as pd, numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
pd.set_option('display.float_format', '{:.4f}'.format)

def get_errors_plot(residuals):
    plt.figure(figsize=(10, 6))
    plt.plot(residuals, color='blue', alpha=0.7)
    plt.axhline(y=0, color='red', linestyle='--', label='Zero Error Line')
    plt.legend()
    plt.show()

def get_residiuals_stats(residuals):
    res = residuals.describe()
    res['2.5%'] = residuals.quantile(0.025)
    res['97.5%'] = residuals.quantile(0.975)
    return res

# %%
X = pd.read_csv('csv\\data_for_modelling.csv', usecols = lambda col: col != 'price')
y = pd.read_csv('csv\\data_for_modelling.csv', usecols = ['price'])['price']

# %%
param_grid = {'n_estimators': [540, 550, 560], 
              'max_depth': [None, 1, 5],
              'min_samples_leaf': [1, 5, 10]
             }

grid_search = GridSearchCV(RandomForestRegressor(random_state = 228), 
                           param_grid, 
                           cv = 5,
                           verbose = 99,  
                           n_jobs = 5, 
                           scoring = 'neg_mean_squared_error'
              )

grid_search.fit(X, y)

residuals = y - grid_search.predict(X)
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
print(get_residiuals_stats(residuals))
get_errors_plot(residuals)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters: {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 540}
# Best score: -1056083746.7345848
# count     6237.000000
# mean      -368.901995
# std      11464.264823
# min     -79778.703704
# 25%      -5302.746914
# 50%      -1152.246914
# 75%       3356.853704
# max      76879.074074
# 2.5%    -21950.821728
# 97.5%    27492.968827
# Name: price, dtype: float64

# %%
param_grid2 = {'n_estimators': [100, 200, 1000], 
              'learning_rate': [0.1, 0.3, 0.7],
              'max_depth': [1, 10, 100]
             }

grid_search2 = GridSearchCV(GradientBoostingRegressor(random_state = 228), 
                           param_grid2, 
                           cv = 5,
                           verbose = 99,  
                           n_jobs = 5, 
                           scoring = 'neg_mean_squared_error'
              )

grid_search2.fit(X, y)

residuals2 = y - grid_search2.predict(X)
print("Best parameters:", grid_search2.best_params_)
print("Best score:", grid_search2.best_score_)
print(get_residiuals_stats(residuals2))
get_errors_plot(residuals2)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Best score: -1143326661.2972
# count    6.237000e+03
# mean    -3.594815e-12
# std      1.360012e+01
# min     -9.432482e+01
# 25%     -7.347607e+00
# 50%     -1.249318e-01
# 75%      7.293229e+00
# max      8.789263e+01
# 2.5%    -2.784553e+01
# 97.5%    2.914074e+01
# Name: price, dtype: float64

# %%
print(get_residiuals_stats(residuals))
get_errors_plot(residuals)
# Out:
# count     6237.00
# mean      -368.90
# std      11464.26
# min     -79778.70
# 25%      -5302.75
# 50%      -1152.25
# 75%       3356.85
# max      76879.07
# 2.5%    -21950.82
# 97.5%    27492.97
# Name: price, dtype: float64

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
get_errors_plot(residuals2)

# %%
Xval = pd.read_csv('csv\\holdout.csv', usecols = lambda col: col != 'price')
yval = pd.read_csv('csv\\holdout.csv', usecols = ['price'])['price']

Xval['author_type_official_representative'] = False

# %%
residuals2 = yval - grid_search2.predict(Xval)
print("Best parameters:", grid_search2.best_params_)
print("Best score:", grid_search2.best_score_)
print(get_residiuals_stats(residuals2))
get_errors_plot(residuals2)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Best score: -1143326661.2972
# count   1000.00
# mean      -0.08
# std       13.49
# min      -91.06
# 25%       -7.41
# 50%       -0.10
# 75%        7.27
# max       70.88
# 2.5%     -26.48
# 97.5%     27.58
# Name: price, dtype: float64
